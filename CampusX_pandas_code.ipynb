# %%
import pandas as pd
import numpy as np

# %%
# custom index

# %%
groups=["CSE","ICE","ETE","EEE"]
id=[1,2,9,101]
pd.Series(group,index=[1,2,9,101])
# Out:
# 1      CSE
# 2      ICE
# 9      ETE
# 101    EEE
# dtype: object

# %%
#Adding name

groups=["CSE","ICE","ETE","EEE"]
id=[1,2,9,101]
new_team=pd.Series(groups,index=id,name='New Groups Member')

# %%
new_team
# Out:
# 1      CSE
# 2      ICE
# 9      ETE
# 101    EEE
# Name: New Groups Member, dtype: object

# %%
#using dictionary

# %%
team={'Football':1,
      'HandBall':2,
      'Cricket':3,
      'Buskatball':4
      }

# %%
list_games=pd.Series(team,name="Games list")
list_games
# Out:
# Football      1
# HandBall      2
# Cricket       3
# Buskatball    4
# Name: Games list, dtype: int64

# %%
list_games.size
# Out:
# 4

# %%
list_games.name
# Out:
# 'Games list'

# %%
list_games.dtype
# Out:
# dtype('int64')

# %%
list_games.is_unique
# Out:
# True

# %%
pd.Series(["A","b","A","C","D","C"]).is_unique
# Out:
# False

# %%
list_games.index
# Out:
# Index(['Football', 'HandBall', 'Cricket', 'Buskatball'], dtype='object')

# %%
list_games.values
# Out:
# array([1, 2, 3, 4])

# %% [markdown]
# #Series using read_csv

# %%
pd.read_csv('/content/Best Universities for Engineering & Technology on BachelorsPortal.csv',squeeze=True)
# Out:
#                                         University_link  \
# 0     https://www.bachelorsportal.com/universities/1...
# 1     https://www.bachelorsportal.com/universities/1...
# 2     https://www.bachelorsportal.com/universities/3...
# 3     https://www.bachelorsportal.com/universities/2...
# 4     https://www.bachelorsportal.com/universities/1...
# ...                                                 ...
# 1464  https://www.bachelorsportal.com/universities/1...
# 1465  https://www.bachelorsportal.com/universities/1...
# 1466  https://www.bachelorsportal.com/universities/1...
# 1467  https://www.bachelorsportal.com/universities/1...
# 1468  https://www.bachelorsportal.com/universities/3...
#
#                                         University_Name  \
# 0                                 University of Chicago
# 1                                   New York University
# 2                               University of Amsterdam
# 3                              University of Copenhagen
# ...

# %%
pd.read_csv('/content/DeviceSpecs.com all category smarthphone ads.csv.csv',index_col='Currency',squeeze=True)
# Out:
#                                               Products_link  \
# Currency
# EUR       https://www.device-specs.io/categories/smartph...
# EUR       https://www.device-specs.io/categories/smartph...
# NaN       https://www.device-specs.io/categories/smartph...
# NaN       https://www.device-specs.io/categories/smartph...
# NaN       https://www.device-specs.io/categories/smartph...
# ...                                                     ...
# NaN       https://www.device-specs.io/categories/smartph...
# NaN       https://www.device-specs.io/categories/smartph...
# NaN       https://www.device-specs.io/categories/smartph...
# NaN       https://www.device-specs.io/categories/smartph...
# EUR       https://www.device-specs.io/categories/smartph...
#
#                    Products_Model  \
# Currency
# EUR           Apple iPhone Xs Max
# EUR                     Oppo A16s
# NaN                     Huawei Y5
# NaN       Apple iPhone 11 Pro Max
# NaN       Apple iPhone 11 Pro Max
# ...

# %%
smartphones=pd.read_csv('/content/DeviceSpecs.com all category smarthphone ads.csv.csv',index_col='Products_link',squeeze=True)

# %%
smartphones
# Out:
#                                                              Products_Model  \
# Products_link
# https://www.device-specs.io/categories/smartpho...      Apple iPhone Xs Max
# https://www.device-specs.io/categories/smartpho...                Oppo A16s
# https://www.device-specs.io/categories/smartpho...                Huawei Y5
# https://www.device-specs.io/categories/smartpho...  Apple iPhone 11 Pro Max
# https://www.device-specs.io/categories/smartpho...  Apple iPhone 11 Pro Max
# ...                                                                     ...
# https://www.device-specs.io/categories/smartpho...          Apple iPhone 12
# https://www.device-specs.io/categories/smartpho...       Samsung Galaxy A53
# https://www.device-specs.io/categories/smartpho...       Samsung Galaxy A53
# https://www.device-specs.io/categories/smartpho...      Samsung Galaxy A52S
# https://www.device-specs.io/categories/smartpho...  Samsung Galaxy Xcover 5
#
# ...

# %% [markdown]
# #Series Methods

# %%
smartphones.head()
# Out:
#                                                              Products_Model  \
# Products_link
# https://www.device-specs.io/categories/smartpho...      Apple iPhone Xs Max
# https://www.device-specs.io/categories/smartpho...                Oppo A16s
# https://www.device-specs.io/categories/smartpho...                Huawei Y5
# https://www.device-specs.io/categories/smartpho...  Apple iPhone 11 Pro Max
# https://www.device-specs.io/categories/smartpho...  Apple iPhone 11 Pro Max
#
#                                                                                      Products_details  \
# Products_link
# https://www.device-specs.io/categories/smartpho...  2018 - 6 cores - 6.5 inch - 256GB - space grey...
# https://www.device-specs.io/categories/smartpho...  2021 - 8 cores - 6.52 inch - 64GB - Black - 59...
# https://www.device-specs.io/categories/smartpho...  2019 - 4 cores - 5.71 inch - 16GB - black - 51...
# ...

# %%
smartphones.head(5
                 )
# Out:
#                                                              Products_Model  \
# Products_link
# https://www.device-specs.io/categories/smartpho...      Apple iPhone Xs Max
# https://www.device-specs.io/categories/smartpho...                Oppo A16s
# https://www.device-specs.io/categories/smartpho...                Huawei Y5
# https://www.device-specs.io/categories/smartpho...  Apple iPhone 11 Pro Max
# https://www.device-specs.io/categories/smartpho...  Apple iPhone 11 Pro Max
#
#                                                                                      Products_details  \
# Products_link
# https://www.device-specs.io/categories/smartpho...  2018 - 6 cores - 6.5 inch - 256GB - space grey...
# https://www.device-specs.io/categories/smartpho...  2021 - 8 cores - 6.52 inch - 64GB - Black - 59...
# https://www.device-specs.io/categories/smartpho...  2019 - 4 cores - 5.71 inch - 16GB - black - 51...
# ...

# %%
smartphones.tail(2)
# Out:
#                                                              Products_Model  \
# Products_link
# https://www.device-specs.io/categories/smartpho...      Samsung Galaxy A52S
# https://www.device-specs.io/categories/smartpho...  Samsung Galaxy Xcover 5
#
#                                                                                      Products_details  \
# Products_link
# https://www.device-specs.io/categories/smartpho...  Qualcomm Snapdragon - 8 cores - 6.5 inch - 128...
# https://www.device-specs.io/categories/smartpho...  2021 - Samsung Exynos 850 - 8 cores - 5.3 inch...
#
#                                                     Price_regular  \
# Products_link
# https://www.device-specs.io/categories/smartpho...         364.26
# https://www.device-specs.io/categories/smartpho...         271.00
#
#                                                    Price_offers Currency  \
# Products_link
# https://www.device-specs.io/categories/smartpho...                   NaN
# ...

# %%
smartphones.sample()
# Out:
#                                                                     Products_Model  \
# Products_link
# https://www.device-specs.io/categories/smartpho...  Samsung Galaxy Note10 SM-N970F
#
#                                                                                      Products_details  \
# Products_link
# https://www.device-specs.io/categories/smartpho...  2019 - 8 cores - 6.3 inch - 256GB - Multicolor...
#
#                                                     Price_regular  \
# Products_link
# https://www.device-specs.io/categories/smartpho...          699.0
#
#                                                    Price_offers Currency  \
# Products_link
# https://www.device-specs.io/categories/smartpho...                   NaN
#
#                                                     Known_price
# Products_link
# https://www.device-specs.io/categories/smartpho...            1

# %%
smartphones.sample(2)
# Out:
#                                                                 Products_Model  \
# Products_link
# https://www.device-specs.io/categories/smartpho...     Apple iPhone 14 Pro Max
# https://www.device-specs.io/categories/smartpho...  Doro 8100 4G Simple Senior
#
#                                                                                      Products_details  \
# Products_link
# https://www.device-specs.io/categories/smartpho...  A16 Bionic chip, 6-core CPU with 2 performance...
# https://www.device-specs.io/categories/smartpho...    2022 - 8 cores - 6.1 inch - 32GB - Black - 8383
#
#                                                     Price_regular  \
# Products_link
# https://www.device-specs.io/categories/smartpho...        1099.99
# https://www.device-specs.io/categories/smartpho...         324.95
#
#                                                    Price_offers Currency  \
# Products_link
# https://www.device-specs.io/categories/smartpho...                   NaN
# ...

# %%
smartphones.value_counts()
# Out:
# Products_Model        Products_details                                                                        Price_regular  Price_offers  Currency  Known_price
# Alcatel 1             2021 - 4 cores - 5 inch - 8GB - Black - 5033DR-2AALWE12-1                               81.45          80.85         EUR       1              1
# Samsung Galaxy M32    2021 - 8 cores - 6.4 inch - 128GB - White - SM-M325FZWGEUB                              253.20         250           EUR       1              1
# Samsung Galaxy A7     2018 - 8 cores - 6 inch - 64GB - Black - SM-A750FZKUPHN                                 289.00         269           EUR       1              1
# Samsung Galaxy A71    Snapdragon 365 - 6.7 inch - 128GB - Prism Cube Black - SM-A716U                         499.99         20.84         USD       1              1
# ...
