# %% [markdown]
# #Loading CSV file in pandas

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/drive/MyDrive/csv/Tripadvisor_Duvai_Resturant.csv', encoding='latin-1')
df.head()
# Out:
#                                      Resturent_Name  \
# 0  Sponsored\nZou Zou Turkish & Lebanese Restaurant
# 1                    1. Couqley French Bistro & Bar
# 2                                   2. The Crossing
# 3                                        3. Nando's
# 4                 4. Ergo Cocktail Bar & Restaurant
#
#                       Food_Type Points of Review  \
# 0   Lebanese, MediterraneanMenu         43 point
# 1  French, European$$ - $$$Menu      2,891 point
# 2      Indian, ContemporaryMenu        437 point
# 3          European, Portuguese        436 point
# 4                 Mediterranean        316 point
#
#                                         Reviews_link  \
# 0  https://www.tripadvisor.com/Restaurant_Review-...
# 1  https://www.tripadvisor.com/Restaurant_Review-...
# 2  https://www.tripadvisor.com/Restaurant_Review-...
# 3  https://www.tripadvisor.com/Restaurant_Review-...
# 4  https://www.tripadvisor.com/Restaurant_Review-...
#
# ...

# %%
df
# Out:
#                                          Resturent_Name  \
# 0      Sponsored\nZou Zou Turkish & Lebanese Restaurant
# 1                        1. Couqley French Bistro & Bar
# 2                                       2. The Crossing
# 3                                            3. Nando's
# 4                     4. Ergo Cocktail Bar & Restaurant
# ...                                                 ...
# 13315                    10797. Chill Lounge Restaurant
# 13316                               10798. Costa Coffee
# 13317                                    10799. Country
# 13318                               10800. Costa Coffee
# 13319                             Sponsored\nThe Robata
#
#                           Food_Type Points of Review  \
# 0       Lebanese, MediterraneanMenu         43 point
# 1      French, European$$ - $$$Menu      2,891 point
# 2          Indian, ContemporaryMenu        437 point
# 3              European, Portuguese        436 point
# ...

# %%
df = pd.read_csv("https://download.bls.gov/pub/time.series/cu/cu.item", sep="\t")

# %%
df
# Out:
#     item_code                                          item_name  \
# 0         AA0                               All items - old base
# 1        AA0R  Purchasing power of the consumer dollar - old ...
# 2         SA0                                          All items
# 3        SA0E                                             Energy
# 4       SA0L1                                All items less food
# ..        ...                                                ...
# 395   SSEA011                                  College textbooks
# 396   SSEE041                                        Smartphones
# 397  SSFV031A           Food at elementary and secondary schools
# 398   SSGE013                                 Infants' equipment
# 399   SSHJ031                                 Infants' furniture
#
#      display_level selectable  sort_sequence
# 0                0          T              2
# 1                0          T            400
# 2                0          T              1
# ...

# %% [markdown]
# Creating Plot area

# %%
import matplotlib.pyplot as plt

# %%
figure=plt.figure()
figure

# %%
figure

# %%
figure=plt.figure().add_axes(rect=[1,1,3,3])
figure
# Out:
# <Axes: >

# %%
figure=plt.figure().add_axes(rect=[0,1,5,3])
figure
# Out:
# <Axes: >

# %%
figure=plt.figure(figsize=(10,10)).add_axes(rect=[2,2,0.5,0.5])

# %%
figsize=(3,3)

# %%
fig2=plt.figure(figsize=(3,5)).add_axes(rect=[1,1,0.5,0.5])

# %%
fig2=plt.figure(figsize=(3,5)).add_axes(rect=[0,0.5,0,0.5])

# %%
fig2=plt.figure(figsize=(3,3)).add_axes(rect=[1,1,1,1])

# %%
fig2=plt.figure(figsize=(2,2)).add_axes(rect=[1,3,3,4])

# %%
fig2=plt.figure(figsize=(10,10)).add_axes(rect=[0,0,0.5,0.5])

# %%
fig4=plt.figure(figsize=(5,6)).add_axes(rect=[1,2,3,4])

# %%
figure=plt.figure(figsize=(5,5))
axes=figure.add_axes(rect=[1,1,0.5,0.5])

# %%
figure=plt.figure(figsize=(5,5))
axes1=figure.add_axes(rect=[1,1,0.5,0.5])
axes2=figure.add_axes(rect=[0.5,0,1,0.5])
axes1.set_title("F-1")
axes2.set_xlabel("X")
# Out:
# Text(0.5, 0, 'X')

# %%
figure=plt.figure(figsize=(5,5))
axes=figure.add_axes(rect=[1,1,1,0.5])
axes=figure.add_axes(rect=[0.5,0.5,1,1])

# %%
figure=plt.figure(figsize=(5,5))
axes=figure.add_axes(rect=[0.5,1,1,1])
axes=figure.add_axes(rect=[0.5,1,1,0.5])

# %%
figure=plt.figure(figsize=(5,5))
axes=figure.add_axes(rect=[0,0,1,1])
axes=figure.add_axes(rect=[1,0,1,1])

# %%
figure=plt.figure(figsize=(5,5))
axes1=figure.add_axes(rect=[1,0,1,1])
axes2=figure.add_axes(rect=[1,0,1,1])
axes3=figure.add_axes(rect=[1,1,0.5,0.6])

# %%
figure=plt.figure(figsize=(5,5))
axes=figure.add_axes(rect=[0,0,1,1])
axes=figure.add_axes(rect=[1,0,1,1])

# %%
figure=plt.figure(figsize=(5,5))
axes=figure.add_axes(rect=[0,0,1,1])
axes=figure.add_axes(rect=[2,0,1,1])

# %%
figure=plt.figure(figsize=(5,5))
axes=figure.add_axes(rect=[0,0,1,1])
axes=figure.add_axes(rect=[2,3,1,1])

# %%
figure=plt.figure(figsize=(5,2))
axes1=figure.add_axes(rect=[0,0,1,1])
axes2=figure.add_axes(rect=[0.1,0.1,0.5,0.5])

# %%
figure=plt.figure(figsize=(2,2))
axes1=figure.add_axes(rect=[0,0,1,1])
axes2=figure.add_axes(rect=[0.1,0.1,0.5,0.5])
axes1.set_xlim(10,30)
# Out:
# (10.0, 30.0)

# %%
plt.subplots(5,1)
# Out:
# (<Figure size 640x480 with 5 Axes>,
#  array([<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >], dtype=object))

# %%
fig=plt.figure(figsize=(3,3))
axes1=fig.add_axes(rect=[0,0,1,1])
axes2=fig.add_axes(rect=[1.5,0,1,1])

axes1.set_ylim(50,120) # set the limit
axes1.set_xlim(70,200)
axes1.set_title('Fig-1')
axes2.set_title('fig-2')

axes1.set_xlabel('X')
axes1.set_ylabel('Y')

axes2.set_xlabel('X')
axes2.set_ylabel('Y')
# Out:
# Text(0, 0.5, 'Y')

# %%
plt.subplots(5,6) # Here will be number of Row is 5 and columns=6
# Out:
# (<Figure size 640x480 with 30 Axes>,
#  array([[<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >],
#         [<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >],
#         [<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >],
#         [<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >],
#         [<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >]],
#        dtype=object))

# %%
plt.subplots(5,6,tight_layout=True) # To fix the layer and overlap
# Out:
# (<Figure size 640x480 with 30 Axes>,
#  array([[<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >],
#         [<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >],
#         [<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >],
#         [<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >],
#         [<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >]],
#        dtype=object))

# %%
plt.subplots(2,2,tight_layout=True)
# Out:
# (<Figure size 640x480 with 4 Axes>,
#  array([[<Axes: >, <Axes: >],
#         [<Axes: >, <Axes: >]], dtype=object))

# %%
plt.subplots(1,1,tight_layout=True)
# Out:
# (<Figure size 640x480 with 1 Axes>, <Axes: >)

# %%
plt.subplots(2,1,tight_layout=True)
# Out:
# (<Figure size 640x480 with 2 Axes>, array([<Axes: >, <Axes: >], dtype=object))

# %%
plt.subplots(1,3,tight_layout=True)
# Out:
# (<Figure size 640x480 with 3 Axes>,
#  array([<Axes: >, <Axes: >, <Axes: >], dtype=object))

# %%
y=plt.subplots(2,1,tight_layout=True)

# %%
y
# Out:
# (<Figure size 640x480 with 2 Axes>, array([<Axes: >, <Axes: >], dtype=object))

# %%
type(y)
# Out:
# tuple

# %%
x=plt.subplots(1,2,tight_layout=True)
x

# %%
fig,axes=plt.subplots(1,2,tight_layout=True)
axes[1].set_title('F-2')
axes[0].set_ylabel('Y')
axes[0].set_xlabel('X')
axes[0].set_title('F-1')
# Out:
# Text(0.5, 1.0, 'F-1')

# %%
x
# Out:
# (<Figure size 432x288 with 2 Axes>, array([<Axes: >, <Axes: >], dtype=object))

# %%
type(x)
# Out:
# tuple

# %%
x[1]
# Out:
# <Axes: >

# %%
figure,((ax1,ax2),(ax3,ax4))=plt.subplots(2,2,tight_layout=True)
ax1.set_title('Fig-1')
ax2.set_xlim(30,100)
ax2.set_title('Fig-2')
# Out:
# Text(0.5, 1.0, 'Fig-2')

# %%
figure,ax1=plt.subplots(1,1)

# %%
type(figure)
# Out:
# matplotlib.figure.Figure

# %%
a=figure,(ax1,ax2)=plt.subplots(1,2)
ax2.set_title("F-2")
# Out:
# Text(0.5, 1.0, 'F-2')

# %%
type(ax1)
# Out:
# numpy.ndarray

# %%
ax1[0]
# Out:
# <Axes: >

# %%
y=figure,ax1=plt.subplots(1,2)

# %%
type(y)
# Out:
# tuple

# %%
type(y[1])
# Out:
# numpy.ndarray

# %% [markdown]
# Adding Lavel

# %%
figure=plt.figure(figsize=(5,5))
axes1=figure.add_axes(rect=[0,0,1,1])
axes2=figure.add_axes(rect=[1.5,0,1,1])

axes1.set_title('Chart 1')
axes2.set_title('Chart 2')

axes1.set_xlabel('x')
axes2.set_ylabel('y')

axes1.set_xlabel('x')
axes1.set_ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %%
ax1[0]
# Out:
# <Axes: >

# %%
figure,(ax1,ax2)=plt.subplots(1,2)
ax1.set_title('First Axes')
ax2.set_title('Second Axes')
# Out:
# Text(0.5, 1.0, 'Second Axes')

# %%
figure,ax=plt.subplots(1,2)
ax[0].set_title('First Axes')
ax[1].set_title('Second Axes')
# Out:
# Text(0.5, 1.0, 'Second Axes')

# %%
figure,ax1=plt.subplots(1,2)
ax1[0].set_title('First Axes')
ax1[1].set_title('Second Axes')
# Out:
# Text(0.5, 1.0, 'Second Axes')

# %%
figure,ax1=plt.subplots(1,2)
ax1[0].set_title('First Axes')
ax1[1].set_title('Second Axes')
ax1[0].set_xlabel('x')
ax1[1].set_ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %%
figure,(ax1,ax2)=plt.subplots(1,2)

# %%
figure,[[ax1,ax2],[ax3,ax4]]=plt.subplots(2,2,tight_layout=True)

ax1.set_title('F-1 ')
ax4.set_title('F-4')
# Out:
# Text(0.5, 1.0, 'F-4')

# %%
figure,[[ax1,ax2,ax3],[ax4,ax5,ax6]]=plt.subplots(3,3,tight_layout=True)
ax6.set_title('F6')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-118-c55bd42bf808> in <cell line: 1>()
# ----> 1 figure,[[ax1,ax2,ax3],[ax4,ax5,ax6]]=plt.subplots(3,3,tight_layout=True)
#       2 ax6.set_title('F6')
#
# ValueError: too many values to unpack (expected 2)

# %%
figure,[[ax1,ax2],[ax3,ax4]]=plt.subplots(2,2, tight_layout=True)
ax1.set_title('ax1')
ax2.set_title('ax2')
ax3.set_title('ax3')
ax4.set_title('ax4')
# Out:
# Text(0.5, 1.0, 'ax4')

# %%
figure,[[ax1,ax2],[ax3,ax4]]=plt.subplots(3,3, tight_layout=True)
ax1.set_title('ax1')
ax2.set_title('ax2')
ax3.set_title('ax3')
ax4.set_title('ax4')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-842408bbd5f2> in <module>
# ----> 1 figure,[[ax1,ax2],[ax3,ax4]]=plt.subplots(3,3, tight_layout=True)
#       2 ax1.set_title('ax1')
#       3 ax2.set_title('ax2')
#       4 ax3.set_title('ax3')
#       5 ax4.set_title('ax4')
#
# ValueError: too many values to unpack (expected 2)
