# %% [markdown]
# # Bar Plot

# %%
import pandas as pd

import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-2-d5df0069828e> in <cell line: 2>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#     101 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#     102   """Mount your Google Drive at the specified mountpoint path."""
# --> 103   return _mount(
#     104       mountpoint,
#     105       force_remount=force_remount,
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     130   )
#     131   if ephemeral:
# --> 132     _message.blocking_request(
#     133         'request_auth', request={'authType': 'dfs_ephemeral'}, timeout_sec=None
# ...

# %%
df=pd.read_csv('/content/drive/MyDrive/Sellenium project/Futurepedia_Ai_Tools_Dataset.csv', encoding='latin-1')
df

# %%
#Rename column  fixed

df.rename(columns={'Ai Tools Name':'AI Tools_N','Per Month':'Monthly cost'},inplace=True)
df

# %%
df_g.columns

# %%
df_g=df[['Types For Use','Monthly cost']]

# %%
df_g
# Out:
#                                           Types For Use Monthly cost
# 0     The meeting recorder that transcribes & summar...       $ 6/mo
# 1     Personal Al assistant for effortless chatting ...      $ 97/mo
# 2     Multipurpose, all-in-one AI app to generate te...      $ 11/mo
# 3     KeywordSearch AI boosts ROI for Google & YouTu...         $29
# 4     AI-powered quiz generator to make unique trivi...    $ 9.99/mo
# ...                                                 ...          ...
# 3010  Produce content quickly & easily to reach busi...         None
# 3011  AI-powered code assistant for data pros to get...         None
# 3012  AI-generated song meanings repository with 200...         None
# 3013                Send cold emails at scale with ease         None
# 3014  AI-powered platform for creating natural, long...         None
#
# [3015 rows x 2 columns]

# %% [markdown]
# \

# %%
df_g=df_g.groupby(by='Types For Use').sum()

# %%
df_g
# Out:
#                                            Categories Monthly cost
# 0                           #summarizer\n#transcriber       $ 6/mo
# 1                     #general writing\n#productivity      $ 97/mo
# 2     #image generator\n#productivity\n#search engine      $ 11/mo
# 3                             #social media assistant         $29
# 4       #social media assistant\n#education assistant    $ 9.99/mo
# ...                                               ...          ...
# 3010                                             #SEO         None
# 3011                            #code assistant\n#SQL         None
# 3012                                           #music         None
# 3013                         #sales\n#email assistant         None
# 3014                                  #text to speech         None
#
# [3015 rows x 2 columns]

# %%
df_g=df[['Categories','Monthly cost']]
df_g
# Out:
#                                            Categories Monthly cost
# 0                           #summarizer\n#transcriber       $ 6/mo
# 1                     #general writing\n#productivity      $ 97/mo
# 2     #image generator\n#productivity\n#search engine      $ 11/mo
# 3                             #social media assistant         $29
# 4       #social media assistant\n#education assistant    $ 9.99/mo
# ...                                               ...          ...
# 3010                                             #SEO         None
# 3011                            #code assistant\n#SQL         None
# 3012                                           #music         None
# 3013                         #sales\n#email assistant         None
# 3014                                  #text to speech         None
#
# [3015 rows x 2 columns]

# %%
df_g=df_g.groupby(by='Categories').sum()
df_g
# Out:
#                                                                                          Monthly cost
# Categories
# #3D                                                 $10 $ 4.99/mo$0.99 $ 12/mo$ 10/mo$ 28/mo.$19.9...
# #3D\n#gaming                                                                         NoneNoneNoneNone
# #3D\n#real estate                                                                             $ 15/mo
# #SEO                                                $ 1/mo$10 $ 25/mo$ 3.99/mo$1 $ 19/mo$19 $ 10/m...
# #SEO\n#copywriting                                  $ 9/mo$5 $ 1/hour$99 NoneNoneNoneNoneNoneNoneN...
# ...                                                                                               ...
# #video editing\n#video generator\n#personalized...                                               $20
# #video generator                                    $ 29/mo.$ 9.95/mo$5 $ 9/mo$ 49/mo$0 $ 15/mo.$0...
# ...

# %%
df.rename(columns={'Ai Tools Name':'AI Tools_N','Per Month':'Monthly cost'},inplace=True)
df
# Out:
#          AI Tools_N                                      Types For Use  \
# 0             tl;dv  The meeting recorder that transcribes & summar...
# 1            Monica  Personal Al assistant for effortless chatting ...
# 2        Bright Eye  Multipurpose, all-in-one AI app to generate te...
# 3     KeywordSearch  KeywordSearch AI boosts ROI for Google & YouTu...
# 4         Quizgecko  AI-powered quiz generator to make unique trivi...
# ...             ...                                                ...
# 3010       Scalenut  Produce content quickly & easily to reach busi...
# 3011     CodeSquire  AI-powered code assistant for data pros to get...
# 3012       Songtell  AI-generated song meanings repository with 200...
# 3013        Pipl.ai                Send cold emails at scale with ease
# 3014    Eleven Labs  AI-powered platform for creating natural, long...
#
#                                            Categories              Pricing  \
# ...

# %%
df_g=df[['Review Count','AI Tools_N']]
df_g

#df_g=df_g.groupby(by='Categories').sum()
df_g
# Out:
#       Review Count     AI Tools_N
# 0                0          tl;dv
# 1                7         Monica
# 2               10     Bright Eye
# 3                6  KeywordSearch
# 4                3      Quizgecko
# ...            ...            ...
# 3010             0       Scalenut
# 3011             0     CodeSquire
# 3012             0       Songtell
# 3013             0        Pipl.ai
# 3014             1    Eleven Labs
#
# [3015 rows x 2 columns]

# %%
df_g=df_g.groupby(by='AI Tools_N').sum()
df_g
# Out:
#             Review Count
# AI Tools_N
# 0xAi                   0
# 10Web                  0
# 2AI                    0
# 2short.ai              1
# 2siq                   0
# ...                  ...
# theGist                0
# tl;dv                  0
# typly                  0
# unbounce               0
# viable                 0
#
# [3007 rows x 1 columns]

# %%
df.rename(columns={'Ai Tools Name':'AI Tools_N','Per Month':'Monthly cost'},inplace=True)
df
# Out:
#          AI Tools_N                                      Types For Use  \
# 0             tl;dv  The meeting recorder that transcribes & summar...
# 1            Monica  Personal Al assistant for effortless chatting ...
# 2        Bright Eye  Multipurpose, all-in-one AI app to generate te...
# 3     KeywordSearch  KeywordSearch AI boosts ROI for Google & YouTu...
# 4         Quizgecko  AI-powered quiz generator to make unique trivi...
# ...             ...                                                ...
# 3010       Scalenut  Produce content quickly & easily to reach busi...
# 3011     CodeSquire  AI-powered code assistant for data pros to get...
# 3012       Songtell  AI-generated song meanings repository with 200...
# 3013        Pipl.ai                Send cold emails at scale with ease
# 3014    Eleven Labs  AI-powered platform for creating natural, long...
#
#                                            Categories              Pricing  \
# ...

# %%
df_g=df[['Types For Use','Monthly cost']]
df_g
# Out:
#                                           Types For Use Monthly cost
# 0     The meeting recorder that transcribes & summar...       $ 6/mo
# 1     Personal Al assistant for effortless chatting ...      $ 97/mo
# 2     Multipurpose, all-in-one AI app to generate te...      $ 11/mo
# 3     KeywordSearch AI boosts ROI for Google & YouTu...         $29
# 4     AI-powered quiz generator to make unique trivi...    $ 9.99/mo
# ...                                                 ...          ...
# 3010  Produce content quickly & easily to reach busi...         None
# 3011  AI-powered code assistant for data pros to get...         None
# 3012  AI-generated song meanings repository with 200...         None
# 3013                Send cold emails at scale with ease         None
# 3014  AI-powered platform for creating natural, long...         None
#
# [3015 rows x 2 columns]

# %%
df_g = df_g.groupby(by='Monthly cost').sum()
df_g
# Out:
#                                                              Types For Use
# Monthly cost
# $ $0                     AI-driven internet marketing platform for a st...
# $ $0.000035/per request  Free AI-powered image creation and editing too...
# $ $0.096/hour            Rasa.io offers the world's only truly personal...
# $ $10                               Generate Drum Loops with AI Technology
# $ $2/mo                  AI-powered tool that generates unique rhyming ...
# ...                                                                    ...
# $9.97                    Streamline lesson planning and improve student...
# $9.99                    Simple tool to generate domain name ideasRemov...
# $99                      Voxqube: AI-powered dubbing service for YouTub...
# $999                      Multiple models for interactive chat experience.
# None                     Increase the Efficiency of your Medical Coding...
#
# [441 rows x 1 columns]

# %%
df_g.columns
# Out:
# Index(['Types For Use'], dtype='object')

# %%
df
# Out:
#          AI Tools_N                                      Types For Use  \
# 0             tl;dv  The meeting recorder that transcribes & summar...
# 1            Monica  Personal Al assistant for effortless chatting ...
# 2        Bright Eye  Multipurpose, all-in-one AI app to generate te...
# 3     KeywordSearch  KeywordSearch AI boosts ROI for Google & YouTu...
# 4         Quizgecko  AI-powered quiz generator to make unique trivi...
# ...             ...                                                ...
# 3010       Scalenut  Produce content quickly & easily to reach busi...
# 3011     CodeSquire  AI-powered code assistant for data pros to get...
# 3012       Songtell  AI-generated song meanings repository with 200...
# 3013        Pipl.ai                Send cold emails at scale with ease
# 3014    Eleven Labs  AI-powered platform for creating natural, long...
#
#                                            Categories              Pricing  \
# ...

# %%
df_g=df[['Categories','Review Count']]
df_g
# Out:
#                                            Categories  Review Count
# 0                           #summarizer\n#transcriber             0
# 1                     #general writing\n#productivity             7
# 2     #image generator\n#productivity\n#search engine            10
# 3                             #social media assistant             6
# 4       #social media assistant\n#education assistant             3
# ...                                               ...           ...
# 3010                                             #SEO             0
# 3011                            #code assistant\n#SQL             0
# 3012                                           #music             0
# 3013                         #sales\n#email assistant             0
# 3014                                  #text to speech             1
#
# [3015 rows x 2 columns]

# %%
df_g=df[['Categories','Review Count']]
df_g
# Out:
#                                            Categories  Review Count
# 0                           #summarizer\n#transcriber             0
# 1                     #general writing\n#productivity             7
# 2     #image generator\n#productivity\n#search engine            10
# 3                             #social media assistant             6
# 4       #social media assistant\n#education assistant             3
# ...                                               ...           ...
# 3010                                             #SEO             0
# 3011                            #code assistant\n#SQL             0
# 3012                                           #music             0
# 3013                         #sales\n#email assistant             0
# 3014                                  #text to speech             1
#
# [3015 rows x 2 columns]

# %%
df_g=df_g.groupby(by='Categories').sum()

# %%
df_g
# Out:
#                                                     Review Count
# Categories
# #3D                                                           10
# #3D\n#gaming                                                   1
# #3D\n#real estate                                              0
# #SEO                                                          25
# #SEO\n#copywriting                                             3
# ...                                                          ...
# #video editing\n#video generator\n#personalized...             7
# #video generator                                              20
# #video generator\n#education assistant                         0
# #video generator\n#gaming                                      1
# #video generator\n#personalized videos                         0
#
# [436 rows x 1 columns]

# %%
#Resetting index of categories to column

df_g.reset_index(inplace=True)
df_g
# Out:
#                                             Categories  Review Count
# 0                                                  #3D            10
# 1                                         #3D\n#gaming             1
# 2                                    #3D\n#real estate             0
# 3                                                 #SEO            25
# 4                                   #SEO\n#copywriting             3
# ..                                                 ...           ...
# 431  #video editing\n#video generator\n#personalize...             7
# 432                                   #video generator            20
# 433             #video generator\n#education assistant             0
# 434                          #video generator\n#gaming             1
# 435             #video generator\n#personalized videos             0
#
# [436 rows x 2 columns]

# %%
df_g.head(5)
# Out:
#            Categories  Review Count
# 0                 #3D            10
# 1        #3D\n#gaming             1
# 2   #3D\n#real estate             0
# 3                #SEO            25
# 4  #SEO\n#copywriting             3

# %%
df
# Out:
#          AI Tools_N                                      Types For Use  \
# 0             tl;dv  The meeting recorder that transcribes & summar...
# 1            Monica  Personal Al assistant for effortless chatting ...
# 2        Bright Eye  Multipurpose, all-in-one AI app to generate te...
# 3     KeywordSearch  KeywordSearch AI boosts ROI for Google & YouTu...
# 4         Quizgecko  AI-powered quiz generator to make unique trivi...
# ...             ...                                                ...
# 3010       Scalenut  Produce content quickly & easily to reach busi...
# 3011     CodeSquire  AI-powered code assistant for data pros to get...
# 3012       Songtell  AI-generated song meanings repository with 200...
# 3013        Pipl.ai                Send cold emails at scale with ease
# 3014    Eleven Labs  AI-powered platform for creating natural, long...
#
#                                            Categories              Pricing  \
# ...

# %%
#Creating a plot area

# %%
df.head(6)
# Out:
#       AI Tools_N                                      Types For Use  \
# 0          tl;dv  The meeting recorder that transcribes & summar...
# 1         Monica  Personal Al assistant for effortless chatting ...
# 2     Bright Eye  Multipurpose, all-in-one AI app to generate te...
# 3  KeywordSearch  KeywordSearch AI boosts ROI for Google & YouTu...
# 4      Quizgecko  AI-powered quiz generator to make unique trivi...
# 5     Lumiere 3D  Generate immersive 3D videos for e-commerce an...
#
#                                         Categories     Pricing Monthly cost  \
# 0                        #summarizer\n#transcriber    Freemium       $ 6/mo
# 1                  #general writing\n#productivity    Freemium      $ 97/mo
# 2  #image generator\n#productivity\n#search engine        Free      $ 11/mo
# 3                          #social media assistant  Free Trial         $29
# 4    #social media assistant\n#education assistant    Freemium    $ 9.99/mo
# ...

# %%
df_g.head(4)
# Out:
#           Categories  Review Count
# 0                #3D            10
# 1       #3D\n#gaming             1
# 2  #3D\n#real estate             0
# 3               #SEO            25

# %% [markdown]
# > Indented block

# %%
fig=plt.figure(figsize=(3,3))

# Creating Axes

axes=fig.add_axes([1,0,2,3])
axes.set_xlabel('Categories')
axes.set_ylabel('Review Count')
axes.set_title('All AI Tools price From Futureidea')

#Creating Bar Plot

plt.bar(x=df_g['Categories'],height=df_g['Review Count'],color=['g'])
plt.show()

# %%
fig=plt.figure(figsize=(3,3))

# Creating Axes

axes=fig.add_axes([1,0,2,3])
axes.set_xlabel('Categories')
axes.set_ylabel('Review Count')
axes.set_title('All AI Tools price From Futureidea')

#Creating Bar Plot

plt.bar(x=df_g['Categories'],height=df_g['Review Count'],color=['b','r','y','g'],edgecolor='blue')
plt.show()

# %%
df_g.sort_values('Review Count',ascending=False,inplace=True)
df_g
# Out:
#                                  Categories  Review Count
# 135                    #education assistant            56
# 173                        #general writing            56
# 260                         #life assistant            54
# 311                           #productivity            51
# 315                                #prompts            42
# ..                                      ...           ...
# 403   #summarizer\n#transcriber\n#fun tools             0
# 360                    #sales\n#copywriting             0
# 361            #sales\n#education assistant             0
# 12                           #SEO\n#prompts             0
# 435  #video generator\n#personalized videos             0
#
# [436 rows x 2 columns]

# %%
#Sorted values from descending order
fig=plt.figure(figsize=(3,3))

# Creating Axes

axes=fig.add_axes([1,0,2,3])
axes.set_xlabel('Categories')
axes.set_ylabel('Review Count')
axes.set_title('All AI Tools price From Futureidea')

#Creating Bar Plot

plt.bar(x=df_g['Categories'],height=df_g['Review Count'],color=['b','r','y','g'],edgecolor='blue')
plt.show()

# %%
df_g.reset_index(inplace=True)
df_g
# Out:
#      level_0  index                              Categories  Review Count
# 0          0    135                    #education assistant            56
# 1          1    173                        #general writing            56
# 2          2    260                         #life assistant            54
# 3          3    311                           #productivity            51
# 4          4    315                                #prompts            42
# ..       ...    ...                                     ...           ...
# 431      431    403   #summarizer\n#transcriber\n#fun tools             0
# 432      432    360                    #sales\n#copywriting             0
# 433      433    361            #sales\n#education assistant             0
# 434      434     12                          #SEO\n#prompts             0
# 435      435    435  #video generator\n#personalized videos             0
#
# [436 rows x 4 columns]

# %%
fig=plt.figure(figsize=(3,3))

# Creating Axes

axes=fig.add_axes([1,0,2,3])
axes.set_xlabel('Categories')
axes.set_ylabel('Review Count')
axes.set_title('All AI Tools price From Futureidea')

#Creating Bar Plot

plt.bar(x=df_g['Categories'],height=df_g['Review Count'],color='white',edgecolor='black')
plt.show()

# %%
fig,(ax1,ax2)=plt.subplots(nrows=1,ncols=2,figsize=(20,8))

ax1.set_xlabel('Categories')
ax1.set_ylabel('Review Count')
ax1.set_title('----')


ax2.set_xlabel('Review Count')
ax2.set_ylabel('Categories')
ax2.set_title('----')

ax1.bar(x=df_g['Categories'],height=df_g['Review Count'])


ax2.barh(y=df_g['Review Count'],width=df_g['Categories'])
# Out:
# <BarContainer object of 436 artists>
